# %%
import pandas as pd

df = pd.read_csv('/kaggle/input/datasets/shaikhmohdharis/practical3/iris.csv')

# %%
grouped = df.groupby('species')

# %%
summary = grouped['sepal_length'].agg(['mean','median','min','max','std'])
print(summary)
# Out:
#              mean  median  min  max       std
# species
# setosa      5.006     5.0  4.3  5.8  0.352490
# versicolor  5.936     5.9  4.9  7.0  0.516171
# virginica   6.588     6.5  4.9  7.9  0.635880

# %%
setosa_list = df[df['species']=='setosa']['sepal_length'].tolist()
versicolor_list = df[df['species']=='versicolor']['sepal_length'].tolist()
virginica_list = df[df['species']=='virginica']['sepal_length'].tolist()

# %%
setosa = df[df['species']=='setosa']
versicolor = df[df['species']=='versicolor']
virginica = df[df['species']=='virginica']

# %%
print("Setosa:\n", setosa.describe())
print("Versicolor:\n", versicolor.describe())
print("Virginica:\n", virginica.describe())
# Out:
# Setosa:
#         sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000
# Versicolor:
#         sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# ...
